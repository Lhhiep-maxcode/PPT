# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
from numpy import dtype


def estimated(a, x):
    res, sz = 0, len(a)
    for i in range(sz - 1, -1, -1):
        res = res * x + a[i]
    return res

def BPTTRR(x, y, deg):
    sums = [np.sum(np.fromiter((xi**j for xi in x), dtype=float), dtype=float) for j in range(deg * 2 + 1)]
    A = np.zeros((deg + 1, deg + 1))    
    b = np.zeros((deg + 1, 1))
    
    for i in range(deg + 1):
        for j in range(deg + 1):
            A[i, j] = sums[i + j]

    for j in range(deg + 1):
        b[j,0] = np.sum(np.fromiter((x[i]**j * y[i] for i in range(len(x))), dtype=float)) 
    return np.linalg.solve(A, b)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return x**2 + 3 * x + 2

x = np.linspace(0, 1, 100)
y = f(x)

max_deg = 2
min_deg = 2

for deg in range(min_deg, max_deg + 1):
    print()
    print('====== BAC', deg, '======')
    a = BPTTRR(x, y, deg)
    print('+ He so cua da thuc:', np.transpose(a))
    p = estimated(a, x)
    print()
    print('+ Bac', deg, ': Sai so:', np.sum(np.fromiter(((y[i]-p[i])**2 for i in range(len(x))), dtype=float)), '\n')
    plt.plot(x, y, color='red', label='truth')
    plt.plot(x, p, color="green", label='estimate')
    plt.legend()
    plt.show()
# Out:
# ====== BAC 2 ======
# + He so cua da thuc: [[2. 3. 1.]]
#
# + Bac 2 : Sai so: 1.0038255018937375e-27

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return x**3

x = np.linspace(0, 2, 200)
y = f(x)

max_deg = 2
min_deg = 2

for deg in range(min_deg, max_deg + 1):
    print()
    print('====== BAC', deg, '======')
    a = BPTTRR(x, y, deg)
    print('+ He so cua da thuc:', np.transpose(a))
    p = estimated(a, x)
    print()
    print('+ Bac', deg, ': Sai so:', np.sum(np.fromiter(((y[i]-p[i])**2 for i in range(len(x))), dtype=float)), '\n')
    plt.plot(x, y, color='red', label='truth')
    plt.plot(x, p, color="green", label='estimate')
    plt.legend()
    plt.show()
# Out:
# ====== BAC 2 ======
# + He so cua da thuc: [[ 0.39399005 -2.39399005  3.        ]]
#
# + Bac 2 : Sai so: 4.709355085149286

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return 1 / x

x = np.linspace(1, 3, 200)
y = f(x)

max_deg = 2
min_deg = 2

for deg in range(min_deg, max_deg + 1):
    print()
    print('====== BAC', deg, '======')
    a = BPTTRR(x, y, deg)
    print('+ He so cua da thuc:', np.transpose(a))
    p = estimated(a, x)
    print()
    print('+ Bac', deg, ': Sai so:', np.sum(np.fromiter(((y[i]-p[i])**2 for i in range(len(x))), dtype=float)), '\n')
    plt.plot(x, y, color='red', label='truth')
    plt.plot(x, p, color="green", label='estimate')
    plt.legend()
    plt.show()
# Out:
# ====== BAC 2 ======
# + He so cua da thuc: [[ 1.72629016 -0.93362834  0.15930681]]
#
# + Bac 2 : Sai so: 0.03720516549712158

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return np.exp(x)

x = np.linspace(0, 2, 200)
y = f(x)

max_deg = 2
min_deg = 2

for deg in range(min_deg, max_deg + 1):
    print()
    print('====== BAC', deg, '======')
    a = BPTTRR(x, y, deg)
    print('+ He so cua da thuc:', np.transpose(a))
    p = estimated(a, x)
    print()
    print('+ Bac', deg, ': Sai so:', np.sum(np.fromiter(((y[i]-p[i])**2 for i in range(len(x))), dtype=float)), '\n')
    plt.plot(x, y, color='red', label='truth')
    plt.plot(x, p, color="green", label='estimate')
    plt.legend()
    plt.show()
# Out:
# ====== BAC 2 ======
# + He so cua da thuc: [[1.16506234 0.08295731 1.45998307]]
#
# + Bac 2 : Sai so: 1.0979207452265551

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return 1 / 2 * np.cos(x) + 1 / 3 * np.sin(2 * x)

x = np.linspace(0, 1, 100)
y = f(x)

max_deg = 2
min_deg = 2

for deg in range(min_deg, max_deg + 1):
    print()
    print('====== BAC', deg, '======')
    a = BPTTRR(x, y, deg)
    print('+ He so cua da thuc:', np.transpose(a))
    p = estimated(a, x)
    print()
    print('+ Bac', deg, ': Sai so:', np.sum(np.fromiter(((y[i]-p[i])**2 for i in range(len(x))), dtype=float)), '\n')
    plt.plot(x, y, color='red', label='truth')
    plt.plot(x, p, color="green", label='estimate')
    plt.legend()
    plt.show()
# Out:
# ====== BAC 2 ======
# + He so cua da thuc: [[ 0.48844841  0.82779974 -0.73668282]]
#
# + Bac 2 : Sai so: 0.001426082749889922

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def f(x):
    return x * np.log(x)

x = np.linspace(1, 3, 200)
y = f(x)

max_deg = 2
min_deg = 2

for deg in range(min_deg, max_deg + 1):
    print()
    print('====== BAC', deg, '======')
    a = BPTTRR(x, y, deg)
    print('+ He so cua da thuc:', np.transpose(a))
    p = estimated(a, x)
    print()
    print('+ Bac', deg, ': Sai so:', np.sum(np.fromiter(((y[i]-p[i])**2 for i in range(len(x))), dtype=float)), '\n')
    plt.plot(x, y, color='red', label='truth')
    plt.plot(x, p, color="green", label='estimate')
    plt.legend()
    plt.show()
# Out:
# ====== BAC 2 ======
# + He so cua da thuc: [[-0.90799347  0.6268746   0.25987756]]
#
# + Bac 2 : Sai so: 0.009991291390866502
