# %%
import math

# %%
def bisection(left, right, tol, iternums=1e5):
    mid = (left + right) / 2
    f_left = f(left)
    f_right = f(right)
    f_mid = f(mid)
    if f_left * f_right > 0:
        print("Left and right are not chosen appropriately, f(left) * f(right) should be less than 0")
        return

    print(mid)
    if ((right - left) / 2) <= tol or iternums == 1:
        return mid
    elif f_left * f_mid > 0:
        return bisection(mid, right, tol, iternums - 1)
    elif f_mid * f_right > 0:
        return bisection(left, mid, tol, iternums - 1)
    return mid

# %% [markdown]
# ![Screenshot 2024-05-31 072226.png](attachment:b2193f2f-329c-401d-b8d0-0efe9606cceb.png)

# %%
f = lambda x: x - 2 ** (-x)
tol = 10 ** -5
bisection(left=0, right=1, tol=tol)
# Out:
# 0.5
# 0.75
# 0.625
# 0.6875
# 0.65625
# 0.640625
# 0.6484375
# 0.64453125
# 0.642578125
# 0.6416015625
# 0.64111328125
# 0.641357421875
# 0.6412353515625
# 0.64117431640625
# 0.641204833984375
# 0.6411895751953125
# 0.6411819458007812
# 0.6411819458007812

# %% [markdown]
# ![image.png](attachment:b29eb1cd-2c55-460c-9354-57f6db918cff.png)

# %%
f = lambda x: math.exp(x) - x ** (2) + 3 * x - 2
tol = 10 ** -5
bisection(left=0, right=1, tol=tol)
# Out:
# 0.5
# 0.25
# 0.375
# 0.3125
# 0.28125
# 0.265625
# 0.2578125
# 0.25390625
# 0.255859375
# 0.2568359375
# 0.25732421875
# 0.257568359375
# 0.2574462890625
# 0.25750732421875
# 0.257537841796875
# 0.2575225830078125
# 0.25753021240234375
# 0.25753021240234375

# %% [markdown]
# ![image.png](attachment:29768532-e9a5-4ddc-a7b1-d7d801afc998.png)

# %%
f = lambda x: 2 * x * math.cos(2 * x) - (x + 1) ** 2
tol = 10 ** -5
print("---------------- -3 <= x <= -2 --------------------")
bisection(left=-3, right=-2, tol=tol)
print()
print("---------------- -1 <= x <= 0 ---------------------")
bisection(left=-1, right=0, tol=tol)
# Out:
# ---------------- -3 <= x <= -2 --------------------
# -2.5
# -2.25
# -2.125
# -2.1875
# -2.21875
# -2.203125
# -2.1953125
# -2.19140625
# -2.189453125
# -2.1904296875
# -2.19091796875
# -2.191162109375
# -2.1912841796875
# -2.19134521484375
# -2.191314697265625
# -2.1912994384765625
# -2.1913070678710938
#
# ---------------- -1 <= x <= 0 ---------------------
# -0.5
# -0.75
# -0.875
# -0.8125
# -0.78125
# -0.796875
# -0.8046875
# -0.80078125
# -0.798828125
# -0.7978515625
# -0.79833984375
# -0.798095703125
# -0.7982177734375
# -0.79815673828125
# -0.798187255859375
# -0.7981719970703125
# -0.7981643676757812
# -0.7981643676757812

# %% [markdown]
# ![image.png](attachment:97d70c1c-eaba-4dc6-92a6-c73fb8331770.png)

# %%
f = lambda x: x * math.cos(x) - 2 * (x ** 2) + 3 * x - 1
tol = 10 ** -5
print("---------------- 0.2 <= x <= 0.3 ----------------")
bisection(left=0.2, right=0.3, tol=tol)
print()
print("---------------- 1.2 <= x <= 1.3 ----------------")
bisection(left=1.2, right=1.3, tol=tol)
# Out:
# ---------------- 0.2 <= x <= 0.3 ----------------
# 0.25
# 0.275
# 0.2875
# 0.29374999999999996
# 0.296875
# 0.2984375
# 0.29765625
# 0.297265625
# 0.2974609375
# 0.29755859375000004
# 0.29750976562500003
# 0.29753417968750007
# 0.29752197265625
# 0.29752807617187504
#
# ---------------- 1.2 <= x <= 1.3 ----------------
# 1.25
# 1.275
# 1.2625
# 1.25625
# 1.259375
# 1.2578125
# 1.25703125
# 1.2566406250000002
# 1.2564453125000001
# 1.2565429687500003
# 1.2565917968750002
# 1.2566162109375
# 1.2566284179687501
# 1.256622314453125
# 1.256622314453125

# %% [markdown]
# ![image.png](attachment:51fd75f0-fe55-427a-997d-f63cbbb25648.png)

# %%
f = lambda x: x ** 3 - x - 1
tol = 10 ** -4
bisection(left=1, right=2, tol=tol, iternums=14)
# Out:
# 1.5
# 1.25
# 1.375
# 1.3125
# 1.34375
# 1.328125
# 1.3203125
# 1.32421875
# 1.326171875
# 1.3251953125
# 1.32470703125
# 1.324951171875
# 1.3248291015625
# 1.32476806640625
# 1.32476806640625
