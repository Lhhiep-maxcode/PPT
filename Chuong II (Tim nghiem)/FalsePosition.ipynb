# %%
import math

# %%
def secantMethod(p0, p1, tol, iternums=10000):
    p = p1 - f(p1) * (p1 - p0) / (f(p1) - f(p0))
    print(p)
    if abs(p - p1) < tol or iternums == 1:
        return p
    return secantMethod(p1, p, tol, iternums - 1)

# %% [markdown]
# ![image.png](attachment:c13be35b-04c0-44dc-bbe4-a60381bb4b5b.png)

# %%
f = lambda x: (20 - x) * x + (20 - x) * x ** (1 / 2) + x * (20 - x) ** (1 / 2) + ((20 - x) * x) ** (1 / 2) - 155.5
df = lambda x: (f(x) - f(x + 1e-9)) / (-1e-9)
tol = 10 ** -4
x = secantMethod(3, 10, tol)
y = 20 - x
print(f"x = {x}, y = {y}")
# Out:
# 8.3051034649907
# 2.766943288773655
# 7.292977322320437
# 6.818723009605599
# 6.4654852418259
# 6.509984228905078
# 6.50797372576119
# 6.507961109738562
# x = 6.507961109738562, y = 13.492038890261437
