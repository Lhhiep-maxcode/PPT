# %%
import math

# %%
def fixedPoint(p0, tol, iternums=10000):
    for i in range(iternums):
        p = g(p0)
        if abs(p - p0) < tol:
            return p
        p0 = p
        print(p)

    return p0

# %% [markdown]
# ![image.png](attachment:076d101f-afd8-4d49-ae55-b07906fb831e.png)

# %%
g = lambda x: ((3 * (x ** 2) + 3)) ** (1 / 4)
tol = 10 ** -2
fixedPoint(p0=1, tol=tol)
# Out:
# 1.5650845800732873
# 1.79357287863573
# 1.8859437430173158
# 1.9228478439840826
# 1.9375075399574273
# 1.9433169298986768

# %% [markdown]
# ![image.png](attachment:3192ddb6-1fcf-4b1f-b84c-9c16f44214af.png)

# %%
g = lambda x: 1 / math.pi * math.asin(-x / 2) + 2
tol = 10 ** -2
fixedPoint(p0=1.1, tol=tol)
# Out:
# 1.8146277057264903
# 1.6381291899676031
# 1.694492969709574
# 1.6782587053656255
# 1.6830650261389684
